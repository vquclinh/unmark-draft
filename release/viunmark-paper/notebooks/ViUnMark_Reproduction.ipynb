# %% [markdown]
# # ViUnMark Reproduction
# This notebook orchestrates the same package and scripts used by the CLI.

# %%
import platform, sys
print(platform.platform())
print(sys.version)

# %%
DATA_ROOT = 'datasets/uit_vsfc'
ASSET_ROOT = 'assets/uit_vsfc'
OUTPUT_ROOT = 'outputs/uit_vsfc'
CONFIG = 'configs/uit_vsfc/paper.json'

# %%
# %pip install -e .

# %%
# !python scripts/verify_assets.py --config {CONFIG} --manifest-only

# %%
# !python scripts/verify_assets.py --config {CONFIG}

# %%
# !python scripts/reproduce_uit_vsfc.py --config {CONFIG} --mode frozen --stage verify

# %% [markdown]
# Prediction, sealing, and scoring cells should be run only after the frozen external assets and user-supplied dataset paths are present.

# %%
# !python scripts/run_diagnostic.py --analysis scale-preflight
